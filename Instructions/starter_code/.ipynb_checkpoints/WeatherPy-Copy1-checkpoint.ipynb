# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#create test list
test_ls = ['hermanus', 'hasaki', 'barrow']
        
# Print the city count to confirm sufficient count
#len(cities)
#print(cities)
print(test_ls)
# Out:
# ['hermanus', 'hasaki', 'barrow']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

new_api = 'baa85d49f99b9efa2601907db53b1ec2'
part_li = []
coord = []
part_di = {}
part_df = pd.DataFrame()

for place in cities:
    city = place

    # Build query URL
    query_url = url + "appid=" + new_api + "&q=" + city
    response = requests.get(query_url)
    part = response.json()
    part_li.append(part)
    part_di.update({city : part})
    coord.append(part)
    time.sleep(1.1)

# %%
#lat_df = pd.DataFrame()
#lat_ls = []
#for city in cities:
    #lat_ls.append(part_di[city])
    
    #lat_df.append(part_di[city])
#for 
#lat_df.append(lat_ls)
#city_df = pd.DataFrame(cities)
#lat_df = pd.DataFrame(lat_ls, index=cities)
#lat_df
pull_di = {}
pull_li = []

#pull2_di works to pull all
pull2_di = {}
part_di['hermanus']
for city in cities:
    pull_di.update(part_di[city])
    pull_li.append(part_di[city])
    pull2_di[city] = part_di[city]
############Try this later at home    
    print(pull2_di)
# Out:
# {'taolanaro': {'cod': '404', 'message': 'city not found'},
#  'mataura': {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 286.48,
#    'pressure': 1005,
#    'humidity': 87,
#    'temp_min': 286.48,
#    'temp_max': 286.48},
#   'wind': {'speed': 8.94, 'deg': 226, 'gust': 16.99},
#   'clouds': {'all': 83},
#   'dt': 1574534124,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1574528065,
#    'sunset': 1574582878},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  'atuona': {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 299.6,
#    'pressure': 1010,
#    'humidity': 75,
#    'temp_min': 299.6,
#    'temp_max': 299.6,
#    'sea_level': 1010,
#    'grnd_level': 1010},
#   'wind': {'speed': 7.22, 'deg': 72},
#   'clouds': {'all': 3},
#   'dt': 1574534125,
#   'sys': {'country': 'PF', 'sunrise': 1574520264, 'sunset': 1574565661},
#   'timezone': -34200,
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  'thai binh': {'coord': {'lon': 106.33, 'lat': 20.45},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 297.15,
#    'pressure': 1014,
#    'humidity': 88,
#    'temp_min': 297.15,
#    'temp_max': 297.15},
#   'visibility': 9000,
#   'wind': {'speed': 2.6, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1574534126,
#   'sys': {'type': 1,
#    'id': 9302,
#    'country': 'VN',
#    'sunrise': 1574550569,
#    'sunset': 1574590395},
#   'timezone': 25200,
#   'id': 1566346,
#   'name': 'Thai Binh',
#   'cod': 200},
#  'pryazha': {'coord': {'lon': 33.62, 'lat': 61.69},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 262.15,
#    'pressure': 1033,
#    'humidity': 92,
#    'temp_min': 262.15,
#    'temp_max': 262.15},
#   'visibility': 10000,
#   'wind': {'speed': 1},
#   'clouds': {'all': 67},
#   'dt': 1574534127,
#   'sys': {'type': 1,
#    'id': 8929,
#    'country': 'RU',
#    'sunrise': 1574489697,
#    'sunset': 1574513340},
#   'timezone': 10800,
#   'id': 504409,
#   'name': 'Pryazha',
#   'cod': 200},
#  'amderma': {'cod': '404', 'message': 'city not found'},
#  'saskylakh': {'coord': {'lon': 114.09, 'lat': 71.97},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 243.2,
#    'pressure': 1017,
#    'humidity': 99,
#    'temp_min': 243.2,
#    'temp_max': 243.2,
#    'sea_level': 1017,
#    'grnd_level': 1005},
#   'wind': {'speed': 1.06, 'deg': 113},
#   'clouds': {'all': 98},
#   'dt': 1574534130,
#   'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 32400,
#   'id': 2017155,
#   'name': 'Saskylakh',
#   'cod': 200},
#  'turan': {'coord': {'lon': 93.92, 'lat': 52.15},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': 251.44,
#    'pressure': 1047,
#    'humidity': 88,
#    'temp_min': 251.44,
#    'temp_max': 251.44,
#    'sea_level': 1047,
#    'grnd_level': 908},
#   'wind': {'speed': 1.58, 'deg': 138},
#   'clouds': {'all': 47},
#   'dt': 1574534131,
#   'sys': {'country': 'RU', 'sunrise': 1574558345, 'sunset': 1574588577},
#   'timezone': 25200,
#   'id': 1488950,
#   'name': 'Turan',
#   'cod': 200},
#  'golyshmanovo': {'coord': {'lon': 68.37, 'lat': 56.4},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 265.58,
#    'pressure': 1023,
#    'humidity': 95,
#    'temp_min': 265.58,
#    'temp_max': 265.58,
#    'sea_level': 1023,
#    'grnd_level': 1008},
#   'wind': {'speed': 3.05, 'deg': 235},
#   'snow': {'3h': 1.31},
#   'clouds': {'all': 100},
#   'dt': 1574534132,
#   'sys': {'country': 'RU', 'sunrise': 1574479211, 'sunset': 1574507143},
#   'timezone': 18000,
#   'id': 1506422,
#   'name': 'Golyshmanovo',
#   'cod': 200},
#  'ushuaia': {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.15,
#    'pressure': 1002,
#    'humidity': 51,
#    'temp_min': 296.15,
#    'temp_max': 296.15},
#   'visibility': 10000,
#   'wind': {'speed': 12.3, 'deg': 340, 'gust': 20.6},
#   'clouds': {'all': 100},
#   'dt': 1574533882,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1574496346,
#    'sunset': 1574555627},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  'pisco': {'coord': {'lon': -76.2, 'lat': -13.71},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 294.36,
#    'pressure': 1013,
#    'humidity': 30,
#    'temp_min': 293.71,
#    'temp_max': 295.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1574534134,
#   'sys': {'type': 1,
#    'id': 8691,
#    'country': 'PE',
#    'sunrise': 1574504816,
#    'sunset': 1574550944},
#   'timezone': -18000,
#   'id': 3932145,
#   'name': 'Pisco',
#   'cod': 200},
#  'brokopondo': {'coord': {'lon': -54.98, 'lat': 5.06},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 306.03,
#    'pressure': 1009,
#    'humidity': 55,
#    'temp_min': 305.93,
#    'temp_max': 306.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 130},
#   'clouds': {'all': 40},
#   'dt': 1574534136,
#   'sys': {'type': 1,
#    'id': 8663,
#    'country': 'SR',
#    'sunrise': 1574501424,
#    'sunset': 1574544149},
#   'timezone': -10800,
#   'id': 3384482,
#   'name': 'Brokopondo',
#   'cod': 200},
#  'debica': {'coord': {'lon': 21.41, 'lat': 50.05},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 275.52,
#    'pressure': 1018,
#    'humidity': 79,
#    'temp_min': 273.15,
#    'temp_max': 278.71},
#   'visibility': 5000,
#   'wind': {'speed': 8.7, 'deg': 100},
#   'clouds': {'all': 90},
#   'dt': 1574534137,
#   'sys': {'type': 1,
#    'id': 1711,
#    'country': 'PL',
#    'sunrise': 1574488761,
#    'sunset': 1574520137},
#   'timezone': 3600,
#   'id': 773380,
#   'name': 'Debica',
#   'cod': 200},
#  'raudeberg': {'coord': {'lon': 5.14, 'lat': 61.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 279.61,
#    'pressure': 1016,
#    'humidity': 70,
#    'temp_min': 279.15,
#    'temp_max': 280.37},
#   'wind': {'speed': 4.1, 'deg': 70},
#   'clouds': {'all': 51},
#   'dt': 1574534138,
#   'sys': {'type': 1,
#    'id': 1616,
#    'country': 'NO',
#    'sunrise': 1574496697,
#    'sunset': 1574520012},
#   'timezone': 3600,
#   'id': 3146487,
#   'name': 'Raudeberg',
#   'cod': 200},
#  'jamestown': {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 282.84,
#    'pressure': 1018,
#    'humidity': 79,
#    'temp_min': 282.84,
#    'temp_max': 282.84,
#    'sea_level': 1018,
#    'grnd_level': 961},
#   'wind': {'speed': 2.4, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1574534139,
#   'sys': {'country': 'AU', 'sunrise': 1574537489, 'sunset': 1574587981},
#   'timezone': 37800,
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  'busselton': {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 284.41,
#    'pressure': 1008,
#    'humidity': 56,
#    'temp_min': 283.15,
#    'temp_max': 286.48},
#   'wind': {'speed': 4.8, 'deg': 150},
#   'clouds': {'all': 37},
#   'dt': 1574534140,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1574543009,
#    'sunset': 1574593623},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  'aykhal': {'coord': {'lon': 111.51, 'lat': 65.95},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 244.15,
#    'pressure': 1007,
#    'humidity': 68,
#    'temp_min': 244.15,
#    'temp_max': 244.15},
#   'visibility': 2500,
#   'wind': {'speed': 1, 'deg': 240},
#   'clouds': {'all': 90},
#   'dt': 1574534141,
#   'sys': {'type': 1,
#    'id': 8846,
#    'country': 'RU',
#    'sunrise': 1574560308,
#    'sunset': 1574578168},
#   'timezone': 32400,
#   'id': 2027296,
#   'name': 'Aykhal',
#   'cod': 200},
#  'ponta do sol': {'coord': {'lon': -46, 'lat': -20.63},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 300.82,
#    'pressure': 1009,
#    'humidity': 59,
#    'temp_min': 300.82,
#    'temp_max': 300.82,
#    'sea_level': 1009,
#    'grnd_level': 913},
#   'wind': {'speed': 4.33, 'deg': 261},
#   'rain': {'3h': 2.63},
#   'clouds': {'all': 13},
#   'dt': 1574534143,
#   'sys': {'country': 'BR', 'sunrise': 1574496879, 'sunset': 1574544382},
#   'timezone': -10800,
#   'id': 3453439,
#   'name': 'Ponta do Sol',
#   'cod': 200},
#  'talnakh': {'coord': {'lon': 88.39, 'lat': 69.49},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 250.15,
#    'pressure': 1014,
#    'humidity': 83,
#    'temp_min': 250.15,
#    'temp_max': 250.15},
#   'visibility': 10000,
#   'wind': {'speed': 6, 'deg': 20},
#   'clouds': {'all': 20},
#   'dt': 1574534144,
#   'sys': {'type': 1,
#    'id': 8951,
#    'country': 'RU',
#    'sunrise': 1574570510,
#    'sunset': 1574579066},
#   'timezone': 25200,
#   'id': 1490256,
#   'name': 'Talnakh',
#   'cod': 200},
#  'avarua': {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 297.15,
#    'pressure': 1010,
#    'humidity': 94,
#    'temp_min': 297.15,
#    'temp_max': 297.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 90},
#   'rain': {'3h': 7.44},
#   'clouds': {'all': 100},
#   'dt': 1574534145,
#   'sys': {'type': 1,
#    'id': 7271,
#    'country': 'CK',
#    'sunrise': 1574524124,
#    'sunset': 1574571763},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  'kapaa': {'coord': {'lon': -159.32, 'lat': 22.08},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 296.95,
#    'pressure': 1017,
#    'humidity': 94,
#    'temp_min': 296.15,
#    'temp_max': 297.59},
#   'visibility': 16093,
#   'wind': {'speed': 9.8, 'deg': 70, 'gust': 17},
#   'rain': {'1h': 0.51},
#   'clouds': {'all': 90},
#   'dt': 1574534146,
#   'sys': {'type': 1,
#    'id': 7873,
#    'country': 'US',
#    'sunrise': 1574528081,
#    'sunset': 1574567585},
#   'timezone': -36000,
#   'id': 5848280,
#   'name': 'Kapaa',
#   'cod': 200},
#  'attawapiskat': {'cod': '404', 'message': 'city not found'},
#  'georgetown': {'coord': {'lon': -58.16, 'lat': 6.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 302.08,
#    'pressure': 1009,
#    'humidity': 79,
#    'temp_min': 301.15,
#    'temp_max': 303.15},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 30},
#   'clouds': {'all': 20},
#   'dt': 1574534082,
#   'sys': {'type': 1,
#    'id': 8776,
#    'country': 'GY',
#    'sunrise': 1574502343,
#    'sunset': 1574544757},
#   'timezone': -14400,
#   'id': 3378644,
#   'name': 'Georgetown',
#   'cod': 200},
#  'opuwo': {'coord': {'lon': 13.84, 'lat': -18.06},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 299.67,
#    'pressure': 1008,
#    'humidity': 21,
#    'temp_min': 299.67,
#    'temp_max': 299.67,
#    'sea_level': 1008,
#    'grnd_level': 871},
#   'wind': {'speed': 5.65, 'deg': 213},
#   'clouds': {'all': 0},
#   'dt': 1574534150,
#   'sys': {'country': 'NA', 'sunrise': 1574482781, 'sunset': 1574529752},
#   'timezone': 7200,
#   'id': 3354077,
#   'name': 'Opuwo',
#   'cod': 200},
#  'pacific grove': {'coord': {'lon': -121.92, 'lat': 36.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 288.36,
#    'pressure': 1024,
#    'humidity': 51,
#    'temp_min': 285.37,
#    'temp_max': 290.93},
#   'visibility': 12874,
#   'wind': {'speed': 1.5, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1574534026,
#   'sys': {'type': 1,
#    'id': 4980,
#    'country': 'US',
#    'sunrise': 1574520821,
#    'sunset': 1574556889},
#   'timezone': -28800,
#   'id': 5380437,
#   'name': 'Pacific Grove',
#   'cod': 200},
#  'east london': {'coord': {'lon': 27.91, 'lat': -33.02},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1014,
#    'humidity': 94,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 210},
#   'clouds': {'all': 75},
#   'dt': 1574533940,
#   'sys': {'type': 1,
#    'id': 1912,
#    'country': 'ZA',
#    'sunrise': 1574477695,
#    'sunset': 1574528083},
#   'timezone': 7200,
#   'id': 1006984,
#   'name': 'East London',
#   'cod': 200},
#  'mahebourg': {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 299.21,
#    'pressure': 1015,
#    'humidity': 88,
#    'temp_min': 299.15,
#    'temp_max': 299.26},
#   'visibility': 10000,
#   'wind': {'speed': 0.84, 'deg': 179},
#   'clouds': {'all': 75},
#   'dt': 1574534154,
#   'sys': {'type': 1,
#    'id': 2061,
#    'country': 'MU',
#    'sunrise': 1574472016,
#    'sunset': 1574519460},
#   'timezone': 14400,
#   'id': 934322,
#   'name': 'Mahebourg',
#   'cod': 200},
#  'luanda': {'coord': {'lon': 13.24, 'lat': -8.83},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 299.15,
#    'pressure': 1009,
#    'humidity': 74,
#    'temp_min': 299.15,
#    'temp_max': 299.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1574533772,
#   'sys': {'type': 1,
#    'id': 2173,
#    'country': 'AO',
#    'sunrise': 1574483806,
#    'sunset': 1574529015},
#   'timezone': 3600,
#   'id': 2240449,
#   'name': 'Luanda',
#   'cod': 200},
#  'borgarnes': {'coord': {'lon': -21.92, 'lat': 64.54},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 275.72,
#    'pressure': 1013,
#    'humidity': 86,
#    'temp_min': 274.82,
#    'temp_max': 277.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.51, 'deg': 42},
#   'clouds': {'all': 100},
#   'dt': 1574534156,
#   'sys': {'type': 1,
#    'id': 91,
#    'country': 'IS',
#    'sunrise': 1574504720,
#    'sunset': 1574524981},
#   'timezone': 0,
#   'id': 3418076,
#   'name': 'Borgarnes',
#   'cod': 200},
#  'coria': {'coord': {'lon': -6.54, 'lat': 39.98},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 282.17,
#    'pressure': 1012,
#    'humidity': 71,
#    'temp_min': 281.48,
#    'temp_max': 283.15},
#   'wind': {'speed': 0.89, 'deg': 251, 'gust': 4.92},
#   'clouds': {'all': 28},
#   'dt': 1574534157,
#   'sys': {'type': 3,
#    'id': 2030597,
#    'country': 'ES',
#    'sunrise': 1574493601,
#    'sunset': 1574528716},
#   'timezone': 3600,
#   'id': 2519234,
#   'name': 'Coria',
#   'cod': 200},
#  'klaksvik': {'coord': {'lon': -6.59, 'lat': 62.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 280.15,
#    'pressure': 1011,
#    'humidity': 100,
#    'temp_min': 280.15,
#    'temp_max': 280.15},
#   'visibility': 9000,
#   'wind': {'speed': 0.5, 'deg': 90},
#   'clouds': {'all': 5},
#   'dt': 1574534158,
#   'sys': {'type': 1,
#    'id': 1596,
#    'country': 'FO',
#    'sunrise': 1574499643,
#    'sunset': 1574522698},
#   'timezone': 0,
#   'id': 2618795,
#   'name': 'Klaksvik',
#   'cod': 200},
#  'cape town': {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 290.34,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 289.82,
#    'temp_max': 291.48},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 310},
#   'clouds': {'all': 20},
#   'dt': 1574533814,
#   'sys': {'type': 1,
#    'id': 1899,
#    'country': 'ZA',
#    'sunrise': 1574479850,
#    'sunset': 1574530485},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  'vila franca do campo': {'coord': {'lon': -25.43, 'lat': 37.72},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1017,
#    'humidity': 88,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 250},
#   'clouds': {'all': 20},
#   'dt': 1574534161,
#   'sys': {'type': 1,
#    'id': 6899,
#    'country': 'PT',
#    'sunrise': 1574497803,
#    'sunset': 1574533584},
#   'timezone': -3600,
#   'id': 3372472,
#   'name': 'Vila Franca do Campo',
#   'cod': 200},
#  'rikitea': {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 295.28,
#    'pressure': 1015,
#    'humidity': 65,
#    'temp_min': 295.28,
#    'temp_max': 295.28,
#    'sea_level': 1015,
#    'grnd_level': 1015},
#   'wind': {'speed': 3.9, 'deg': 162},
#   'clouds': {'all': 10},
#   'dt': 1574534162,
#   'sys': {'country': 'PF', 'sunrise': 1574517966, 'sunset': 1574566010},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  'hobart': {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 282.83,
#    'pressure': 1013,
#    'humidity': 53,
#    'temp_min': 282.04,
#    'temp_max': 283.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 340},
#   'clouds': {'all': 75},
#   'dt': 1574534163,
#   'sys': {'type': 1,
#    'id': 9545,
#    'country': 'AU',
#    'sunrise': 1574533880,
#    'sunset': 1574587400},
#   'timezone': 39600,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  'barquisimeto': {'coord': {'lon': -69.32, 'lat': 10.07},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 299.95,
#    'pressure': 1010,
#    'humidity': 55,
#    'temp_min': 299.95,
#    'temp_max': 299.95,
#    'sea_level': 1010,
#    'grnd_level': 913},
#   'wind': {'speed': 2.5, 'deg': 347},
#   'clouds': {'all': 65},
#   'dt': 1574534164,
#   'sys': {'country': 'VE', 'sunrise': 1574505318, 'sunset': 1574547140},
#   'timezone': -14400,
#   'id': 3648522,
#   'name': 'Barquisimeto',
#   'cod': 200},
#  'upernavik': {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 268.02,
#    'pressure': 1008,
#    'humidity': 60,
#    'temp_min': 268.02,
#    'temp_max': 268.02,
#    'sea_level': 1008,
#    'grnd_level': 1006},
#   'wind': {'speed': 5.04, 'deg': 101},
#   'clouds': {'all': 100},
#   'dt': 1574534165,
#   'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'timezone': -10800,
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  'faanui': {'coord': {'lon': -151.75, 'lat': -16.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 300.3,
#    'pressure': 1011,
#    'humidity': 78,
#    'temp_min': 300.3,
#    'temp_max': 300.3,
#    'sea_level': 1011,
#    'grnd_level': 1010},
#   'wind': {'speed': 7.55, 'deg': 73},
#   'clouds': {'all': 92},
#   'dt': 1574534167,
#   'sys': {'country': 'PF', 'sunrise': 1574522679, 'sunset': 1574569352},
#   'timezone': -36000,
#   'id': 4034551,
#   'name': 'Faanui',
#   'cod': 200},
#  'stournaraiika': {'cod': '404', 'message': 'city not found'},
#  'lebu': {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 289.15,
#    'pressure': 1026,
#    'humidity': 82,
#    'temp_min': 289.15,
#    'temp_max': 289.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1574534169,
#   'sys': {'type': 1,
#    'id': 2453,
#    'country': 'ET',
#    'sunrise': 1574479277,
#    'sunset': 1574521306},
#   'timezone': 10800,
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  'komsomolskiy': {'coord': {'lon': 63.78, 'lat': 67.55},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 259.51,
#    'pressure': 1027,
#    'humidity': 85,
#    'temp_min': 259.51,
#    'temp_max': 259.51,
#    'sea_level': 1027,
#    'grnd_level': 1005},
#   'wind': {'speed': 1.3, 'deg': 77},
#   'clouds': {'all': 100},
#   'dt': 1574534170,
#   'sys': {'country': 'RU', 'sunrise': 1574486704, 'sunset': 1574501854},
#   'timezone': 10800,
#   'id': 1486910,
#   'name': 'Komsomolskiy',
#   'cod': 200},
#  'punta arenas': {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 292.46,
#    'pressure': 999,
#    'humidity': 45,
#    'temp_min': 289.82,
#    'temp_max': 296.15},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 150},
#   'clouds': {'all': 100},
#   'dt': 1574534171,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1574497489,
#    'sunset': 1574555732},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  'fulitun': {'cod': '404', 'message': 'city not found'},
#  'vaini': {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 292.08,
#    'pressure': 1013,
#    'humidity': 64,
#    'temp_min': 292.08,
#    'temp_max': 292.08,
#    'sea_level': 1013,
#    'grnd_level': 938},
#   'wind': {'speed': 3.41, 'deg': 76},
#   'clouds': {'all': 0},
#   'dt': 1574534174,
#   'sys': {'country': 'IN', 'sunrise': 1574557712, 'sunset': 1574598537},
#   'timezone': 19800,
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  'tessalit': {'coord': {'lon': 1.01, 'lat': 20.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 298.87,
#    'pressure': 1012,
#    'humidity': 12,
#    'temp_min': 298.87,
#    'temp_max': 298.87,
#    'sea_level': 1012,
#    'grnd_level': 957},
#   'wind': {'speed': 4.1, 'deg': 297},
#   'clouds': {'all': 0},
#   'dt': 1574534175,
#   'sys': {'country': 'ML', 'sunrise': 1574489393, 'sunset': 1574529299},
#   'timezone': 0,
#   'id': 2449893,
#   'name': 'Tessalit',
#   'cod': 200},
#  'bambous virieux': {'coord': {'lon': 57.76, 'lat': -20.34},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 299.21,
#    'pressure': 1015,
#    'humidity': 88,
#    'temp_min': 299.15,
#    'temp_max': 299.26},
#   'visibility': 10000,
#   'wind': {'speed': 5.33, 'deg': 1},
#   'clouds': {'all': 75},
#   'dt': 1574534176,
#   'sys': {'type': 1,
#    'id': 2061,
#    'country': 'MU',
#    'sunrise': 1574472009,
#    'sunset': 1574519439},
#   'timezone': 14400,
#   'id': 1106677,
#   'name': 'Bambous Virieux',
#   'cod': 200},
#  'mildura': {'coord': {'lon': 142.16, 'lat': -34.18},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 285.42,
#    'pressure': 1018,
#    'humidity': 58,
#    'temp_min': 284.82,
#    'temp_max': 286.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 170},
#   'clouds': {'all': 24},
#   'dt': 1574534177,
#   'sys': {'type': 1,
#    'id': 9550,
#    'country': 'AU',
#    'sunrise': 1574536502,
#    'sunset': 1574587259},
#   'timezone': 39600,
#   'id': 2157698,
#   'name': 'Mildura',
#   'cod': 200},
#  'kailua': {'coord': {'lon': -157.74, 'lat': 21.39},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.59,
#    'pressure': 1015,
#    'humidity': 74,
#    'temp_min': 297.04,
#    'temp_max': 299.26},
#   'visibility': 16093,
#   'wind': {'speed': 5.1, 'deg': 70, 'gust': 10.8},
#   'clouds': {'all': 75},
#   'dt': 1574534179,
#   'sys': {'type': 1,
#    'id': 7877,
#    'country': 'US',
#    'sunrise': 1574527631,
#    'sunset': 1574567277},
#   'timezone': -36000,
#   'id': 5847486,
#   'name': 'Kailua',
#   'cod': 200},
#  'tsihombe': {'cod': '404', 'message': 'city not found'},
#  'borazjan': {'coord': {'lon': 51.21, 'lat': 29.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 292.15,
#    'pressure': 1019,
#    'humidity': 52,
#    'temp_min': 292.15,
#    'temp_max': 292.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.39, 'deg': 352},
#   'clouds': {'all': 0},
#   'dt': 1574534181,
#   'sys': {'type': 1,
#    'id': 7444,
#    'country': 'IR',
#    'sunrise': 1574478312,
#    'sunset': 1574516280},
#   'timezone': 12600,
#   'id': 140097,
#   'name': 'Borazjan',
#   'cod': 200},
#  'hilo': {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 293.52,
#    'pressure': 1016,
#    'humidity': 88,
#    'temp_min': 283.71,
#    'temp_max': 296.48},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 210},
#   'rain': {'1h': 2.03},
#   'clouds': {'all': 75},
#   'dt': 1574534129,
#   'sys': {'type': 1,
#    'id': 7881,
#    'country': 'US',
#    'sunrise': 1574526822,
#    'sunset': 1574566808},
#   'timezone': -36000,
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  'cherskiy': {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 241.21,
#    'pressure': 1020,
#    'humidity': 95,
#    'temp_min': 241.21,
#    'temp_max': 241.21,
#    'sea_level': 1020,
#    'grnd_level': 1018},
#   'wind': {'speed': 3.41, 'deg': 149},
#   'clouds': {'all': 98},
#   'dt': 1574534183,
#   'sys': {'country': 'RU', 'sunrise': 1574551523, 'sunset': 1574563050},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  'mys shmidta': {'cod': '404', 'message': 'city not found'},
#  'batagay': {'coord': {'lon': 134.64, 'lat': 67.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 234.77,
#    'pressure': 1023,
#    'humidity': 94,
#    'temp_min': 234.77,
#    'temp_max': 234.77,
#    'sea_level': 1023,
#    'grnd_level': 983},
#   'wind': {'speed': 1.19, 'deg': 185},
#   'clouds': {'all': 0},
#   'dt': 1574534186,
#   'sys': {'country': 'RU', 'sunrise': 1574556441, 'sunset': 1574570931},
#   'timezone': 36000,
#   'id': 2027044,
#   'name': 'Batagay',
#   'cod': 200},
#  'mar del plata': {'coord': {'lon': -67.52, 'lat': -46.43},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 291.13,
#    'pressure': 1004,
#    'humidity': 45,
#    'temp_min': 291.13,
#    'temp_max': 291.13,
#    'sea_level': 1004,
#    'grnd_level': 995},
#   'wind': {'speed': 5.8, 'deg': 103},
#   'clouds': {'all': 100},
#   'dt': 1574534187,
#   'sys': {'country': 'AR', 'sunrise': 1574498362, 'sunset': 1574553231},
#   'timezone': -10800,
#   'id': 3863379,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  'faya': {'coord': {'lon': 42.45, 'lat': 18.39},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 288.18,
#    'pressure': 1025,
#    'humidity': 93,
#    'temp_min': 287.15,
#    'temp_max': 289.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.49, 'deg': 245},
#   'clouds': {'all': 5},
#   'dt': 1574534188,
#   'sys': {'type': 1,
#    'id': 7396,
#    'country': 'SA',
#    'sunrise': 1574479265,
#    'sunset': 1574519533},
#   'timezone': 10800,
#   'id': 110690,
#   'name': 'Faya',
#   'cod': 200},
#  'cairns': {'coord': {'lon': 145.77, 'lat': -16.92},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 293.19,
#    'pressure': 1011,
#    'humidity': 88,
#    'temp_min': 290.93,
#    'temp_max': 294.26},
#   'visibility': 10000,
#   'wind': {'speed': 4.49, 'deg': 172},
#   'clouds': {'all': 75},
#   'dt': 1574534189,
#   'sys': {'type': 1,
#    'id': 9490,
#    'country': 'AU',
#    'sunrise': 1574537631,
#    'sunset': 1574584397},
#   'timezone': 36000,
#   'id': 2172797,
#   'name': 'Cairns',
#   'cod': 200},
#  'bathsheba': {'coord': {'lon': -59.52, 'lat': 13.22},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.15,
#    'pressure': 1010,
#    'humidity': 62,
#    'temp_min': 304.15,
#    'temp_max': 304.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 100},
#   'clouds': {'all': 40},
#   'dt': 1574534190,
#   'sys': {'type': 1,
#    'id': 8772,
#    'country': 'BB',
#    'sunrise': 1574503255,
#    'sunset': 1574544498},
#   'timezone': -14400,
#   'id': 3374083,
#   'name': 'Bathsheba',
#   'cod': 200},
#  'puerto ayora': {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 297.03,
#    'pressure': 1014,
#    'humidity': 57,
#    'temp_min': 295.93,
#    'temp_max': 298.15},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1574534192,
#   'sys': {'type': 1,
#    'id': 8521,
#    'country': 'EC',
#    'sunrise': 1574509399,
#    'sunset': 1574553155},
#   'timezone': -21600,
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  'karousades': {'cod': '404', 'message': 'city not found'},
#  'tasiilaq': {'coord': {'lon': -37.64, 'lat': 65.61},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 268.15,
#    'pressure': 1023,
#    'humidity': 67,
#    'temp_min': 268.15,
#    'temp_max': 268.15},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 160},
#   'clouds': {'all': 20},
#   'dt': 1574534194,
#   'sys': {'type': 1,
#    'id': 81,
#    'country': 'GL',
#    'sunrise': 1574509294,
#    'sunset': 1574527954},
#   'timezone': -10800,
#   'id': 3424607,
#   'name': 'Tasiilaq',
#   'cod': 200},
#  'batticaloa': {'coord': {'lon': 81.69, 'lat': 7.71},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 296.66,
#    'pressure': 1012,
#    'humidity': 93,
#    'temp_min': 296.66,
#    'temp_max': 296.66,
#    'sea_level': 1012,
#    'grnd_level': 1002},
#   'wind': {'speed': 1.15, 'deg': 264},
#   'rain': {'3h': 0.13},
#   'clouds': {'all': 39},
#   'dt': 1574534195,
#   'sys': {'country': 'LK', 'sunrise': 1574555276, 'sunset': 1574597517},
#   'timezone': 19800,
#   'id': 1250161,
#   'name': 'Batticaloa',
#   'cod': 200},
#  'pontianak': {'coord': {'lon': 109.34, 'lat': -0.02},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 296.53,
#    'pressure': 1009,
#    'humidity': 96,
#    'temp_min': 296.53,
#    'temp_max': 296.53,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'wind': {'speed': 1.03, 'deg': 328},
#   'rain': {'3h': 0.88},
#   'clouds': {'all': 100},
#   'dt': 1574534197,
#   'sys': {'country': 'ID', 'sunrise': 1574547945, 'sunset': 1574591573},
#   'timezone': 25200,
#   'id': 1630789,
#   'name': 'Pontianak',
#   'cod': 200},
#  'chapais': {'coord': {'lon': -74.86, 'lat': 49.78},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 267.15,
#    'pressure': 999,
#    'humidity': 92,
#    'temp_min': 267.15,
#    'temp_max': 267.15},
#   'visibility': 14484,
#   'wind': {'speed': 6.2, 'deg': 210, 'gust': 10.3},
#   'clouds': {'all': 90},
#   'dt': 1574534198,
#   'sys': {'type': 1,
#    'id': 859,
#    'country': 'CA',
#    'sunrise': 1574511829,
#    'sunset': 1574543288},
#   'timezone': -18000,
#   'id': 5919850,
#   'name': 'Chapais',
#   'cod': 200},
#  'saint george': {'coord': {'lon': 22.34, 'lat': 39.45},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 287.83,
#    'pressure': 1018,
#    'humidity': 82,
#    'temp_min': 287.15,
#    'temp_max': 288.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.25, 'deg': 108},
#   'clouds': {'all': 40},
#   'dt': 1574534199,
#   'sys': {'type': 1,
#    'id': 6629,
#    'country': 'GR',
#    'sunrise': 1574486584,
#    'sunset': 1574521868},
#   'timezone': 7200,
#   'id': 262462,
#   'name': 'Saint George',
#   'cod': 200},
#  'butaritari': {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 301.8,
#    'pressure': 1007,
#    'humidity': 67,
#    'temp_min': 301.8,
#    'temp_max': 301.8,
#    'sea_level': 1007,
#    'grnd_level': 1007},
#   'wind': {'speed': 4.19, 'deg': 94},
#   'clouds': {'all': 54},
#   'dt': 1574534200,
#   'sys': {'country': 'KI', 'sunrise': 1574532989, 'sunset': 1574576067},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  'bredasdorp': {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 291.43,
#    'pressure': 1016,
#    'humidity': 63,
#    'temp_min': 290.93,
#    'temp_max': 292.15},
#   'wind': {'speed': 5.7, 'deg': 300},
#   'clouds': {'all': 17},
#   'dt': 1574534201,
#   'sys': {'type': 1,
#    'id': 1966,
#    'country': 'ZA',
#    'sunrise': 1574479378,
#    'sunset': 1574530178},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  'oriximina': {'coord': {'lon': -55.87, 'lat': -1.77},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 303.02,
#    'pressure': 1009,
#    'humidity': 67,
#    'temp_min': 303.02,
#    'temp_max': 303.02,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'wind': {'speed': 2.84, 'deg': 102},
#   'rain': {'3h': 4.5},
#   'clouds': {'all': 39},
#   'dt': 1574534038,
#   'sys': {'country': 'BR', 'sunrise': 1574501030, 'sunset': 1574544970},
#   'timezone': -10800,
#   'id': 3393471,
#   'name': 'Oriximina',
#   'cod': 200},
#  'port hueneme': {'coord': {'lon': -119.2, 'lat': 34.15},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1021,
#    'humidity': 28,
#    'temp_min': 290.93,
#    'temp_max': 295.15},
#   'visibility': 16093,
#   'wind': {'speed': 8.2, 'deg': 70, 'gust': 12.3},
#   'clouds': {'all': 1},
#   'dt': 1574534204,
#   'sys': {'type': 1,
#    'id': 3649,
#    'country': 'US',
#    'sunrise': 1574519835,
#    'sunset': 1574556570},
#   'timezone': -28800,
#   'id': 5384339,
#   'name': 'Port Hueneme',
#   'cod': 200},
#  'bluff': {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 292.83,
#    'pressure': 1014,
#    'humidity': 89,
#    'temp_min': 292.83,
#    'temp_max': 292.83,
#    'sea_level': 1014,
#    'grnd_level': 993},
#   'wind': {'speed': 3.83, 'deg': 103},
#   'clouds': {'all': 0},
#   'dt': 1574534205,
#   'sys': {'country': 'AU', 'sunrise': 1574536144, 'sunset': 1574584300},
#   'timezone': 36000,
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  'kodiak': {'coord': {'lon': -94.76, 'lat': 39.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 278.85,
#    'pressure': 1014,
#    'humidity': 60,
#    'temp_min': 278.15,
#    'temp_max': 279.82},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1574534206,
#   'sys': {'type': 1,
#    'id': 5924,
#    'country': 'US',
#    'sunrise': 1574514785,
#    'sunset': 1574549886},
#   'timezone': -21600,
#   'id': 4407665,
#   'name': 'Kodiak',
#   'cod': 200},
#  'kavieng': {'coord': {'lon': 150.8, 'lat': -2.57},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 300.59,
#    'pressure': 1006,
#    'humidity': 77,
#    'temp_min': 300.59,
#    'temp_max': 300.59,
#    'sea_level': 1006,
#    'grnd_level': 1007},
#   'wind': {'speed': 3.89, 'deg': 202},
#   'clouds': {'all': 83},
#   'dt': 1574534207,
#   'sys': {'country': 'PG', 'sunrise': 1574537764, 'sunset': 1574581849},
#   'timezone': 36000,
#   'id': 2094342,
#   'name': 'Kavieng',
#   'cod': 200},
#  'hermanus': {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 290.93,
#    'pressure': 1012,
#    'humidity': 83,
#    'temp_min': 290.93,
#    'temp_max': 290.93},
#   'wind': {'speed': 0.45, 'deg': 262, 'gust': 2.68},
#   'rain': {'3h': 0.13},
#   'clouds': {'all': 33},
#   'dt': 1574534208,
#   'sys': {'type': 3,
#    'id': 2006131,
#    'country': 'ZA',
#    'sunrise': 1574479585,
#    'sunset': 1574530355},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  'lagoa': {'coord': {'lon': -8.45, 'lat': 37.14},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 287.35,
#    'pressure': 1015,
#    'humidity': 71,
#    'temp_min': 287.04,
#    'temp_max': 287.59},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 290},
#   'clouds': {'all': 54},
#   'dt': 1574534154,
#   'sys': {'type': 1,
#    'id': 6892,
#    'country': 'PT',
#    'sunrise': 1574493642,
#    'sunset': 1574529592},
#   'timezone': 0,
#   'id': 2267254,
#   'name': 'Lagoa',
#   'cod': 200},
#  'floro': {'coord': {'lon': 5.03, 'lat': 61.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 277.74,
#    'pressure': 1016,
#    'humidity': 70,
#    'temp_min': 272.04,
#    'temp_max': 280.37},
#   'wind': {'speed': 4.1, 'deg': 70},
#   'clouds': {'all': 90},
#   'dt': 1574534211,
#   'sys': {'type': 1,
#    'id': 1616,
#    'country': 'NO',
#    'sunrise': 1574496526,
#    'sunset': 1574520236},
#   'timezone': 3600,
#   'id': 3156980,
#   'name': 'Floro',
#   'cod': 200},
#  'port alfred': {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1015,
#    'humidity': 83,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'wind': {'speed': 0.89, 'deg': 261, 'gust': 3.58},
#   'clouds': {'all': 82},
#   'dt': 1574534212,
#   'sys': {'type': 3,
#    'id': 2011314,
#    'country': 'ZA',
#    'sunrise': 1574477864,
#    'sunset': 1574528404},
#   'timezone': 7200,
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  'guarapari': {'coord': {'lon': -40.5, 'lat': -20.67},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 303.03,
#    'pressure': 1006,
#    'humidity': 62,
#    'temp_min': 302.59,
#    'temp_max': 304.15},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 20},
#   'rain': {'3h': 1.94},
#   'clouds': {'all': 73},
#   'dt': 1574534213,
#   'sys': {'type': 1,
#    'id': 8474,
#    'country': 'BR',
#    'sunrise': 1574495555,
#    'sunset': 1574543066},
#   'timezone': -10800,
#   'id': 3461888,
#   'name': 'Guarapari',
#   'cod': 200},
#  'myaundzha': {'coord': {'lon': 147.18, 'lat': 63.05},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': 244.21,
#    'pressure': 1017,
#    'humidity': 98,
#    'temp_min': 244.21,
#    'temp_max': 244.21,
#    'sea_level': 1017,
#    'grnd_level': 895},
#   'wind': {'speed': 0.66, 'deg': 297},
#   'snow': {'3h': 0.25},
#   'clouds': {'all': 100},
#   'dt': 1574534214,
#   'sys': {'country': 'RU', 'sunrise': 1574549690, 'sunset': 1574571661},
#   'timezone': 39600,
#   'id': 2123100,
#   'name': 'Myaundzha',
#   'cod': 200},
#  'yellowknife': {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 268.15,
#    'pressure': 986,
#    'humidity': 100,
#    'temp_min': 268.15,
#    'temp_max': 268.15},
#   'visibility': 24140,
#   'wind': {'speed': 4.1, 'deg': 300},
#   'clouds': {'all': 90},
#   'dt': 1574534121,
#   'sys': {'type': 1,
#    'id': 1007,
#    'country': 'CA',
#    'sunrise': 1574525680,
#    'sunset': 1574548411},
#   'timezone': -25200,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  'chulman': {'coord': {'lon': 124.9, 'lat': 56.84},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 243.81,
#    'pressure': 1032,
#    'humidity': 99,
#    'temp_min': 243.81,
#    'temp_max': 243.81,
#    'sea_level': 1032,
#    'grnd_level': 924},
#   'wind': {'speed': 1.52, 'deg': 323},
#   'clouds': {'all': 100},
#   'dt': 1574534217,
#   'sys': {'country': 'RU', 'sunrise': 1574552291, 'sunset': 1574579757},
#   'timezone': 32400,
#   'id': 2025261,
#   'name': 'Chulman',
#   'cod': 200},
#  'marshall': {'coord': {'lon': -93.2, 'lat': 39.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 277.7,
#    'pressure': 1014,
#    'humidity': 69,
#    'temp_min': 276.48,
#    'temp_max': 279.26},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1574534218,
#   'sys': {'type': 1,
#    'id': 4894,
#    'country': 'US',
#    'sunrise': 1574514285,
#    'sunset': 1574549638},
#   'timezone': -21600,
#   'id': 4397211,
#   'name': 'Marshall',
#   'cod': 200},
#  'kenai': {'coord': {'lon': -151.26, 'lat': 60.55},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 274.6,
#    'pressure': 990,
#    'humidity': 69,
#    'temp_min': 273.15,
#    'temp_max': 275.37},
#   'visibility': 16093,
#   'wind': {'speed': 5.7, 'deg': 160},
#   'clouds': {'all': 1},
#   'dt': 1574534219,
#   'sys': {'type': 1,
#    'id': 7680,
#    'country': 'US',
#    'sunrise': 1574533601,
#    'sunset': 1574558195},
#   'timezone': -32400,
#   'id': 5866063,
#   'name': 'Kenai',
#   'cod': 200},
#  'clyde river': {'coord': {'lon': -68.59, 'lat': 70.47},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 266.15,
#    'pressure': 989,
#    'humidity': 100,
#    'temp_min': 266.15,
#    'temp_max': 266.15},
#   'visibility': 2012,
#   'wind': {'speed': 10.3, 'deg': 300},
#   'clouds': {'all': 90},
#   'dt': 1574534220,
#   'sys': {'type': 1,
#    'id': 776,
#    'country': 'CA',
#    'sunrise': 1574525135,
#    'sunset': 1574526972},
#   'timezone': -18000,
#   'id': 5924351,
#   'name': 'Clyde River',
#   'cod': 200},
#  'ceres': {'coord': {'lon': -49.6, 'lat': -15.31},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 296.56,
#    'pressure': 1009,
#    'humidity': 78,
#    'temp_min': 296.56,
#    'temp_max': 296.56,
#    'sea_level': 1009,
#    'grnd_level': 940},
#   'wind': {'speed': 1.61, 'deg': 234},
#   'clouds': {'all': 100},
#   'dt': 1574534222,
#   'sys': {'country': 'BR', 'sunrise': 1574498278, 'sunset': 1574544712},
#   'timezone': -10800,
#   'id': 3466436,
#   'name': 'Ceres',
#   'cod': 200},
#  'port elizabeth': {'coord': {'lon': -74.98, 'lat': 39.31},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 279.95,
#    'pressure': 1016,
#    'humidity': 36,
#    'temp_min': 278.71,
#    'temp_max': 281.48},
#   'visibility': 16093,
#   'wind': {'speed': 1.59, 'deg': 207},
#   'clouds': {'all': 1},
#   'dt': 1574534223,
#   'sys': {'type': 1,
#    'id': 4902,
#    'country': 'US',
#    'sunrise': 1574509937,
#    'sunset': 1574545238},
#   'timezone': -18000,
#   'id': 4501427,
#   'name': 'Port Elizabeth',
#   'cod': 200},
#  'nanortalik': {'coord': {'lon': -45.24, 'lat': 60.14},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': 274.39,
#    'pressure': 1018,
#    'humidity': 65,
#    'temp_min': 274.39,
#    'temp_max': 274.39,
#    'sea_level': 1018,
#    'grnd_level': 1011},
#   'wind': {'speed': 2.9, 'deg': 47},
#   'clouds': {'all': 35},
#   'dt': 1574534224,
#   'sys': {'country': 'GL', 'sunrise': 1574507931, 'sunset': 1574532966},
#   'timezone': -10800,
#   'id': 3421765,
#   'name': 'Nanortalik',
#   'cod': 200},
#  'deli tua': {'coord': {'lon': 98.69, 'lat': 3.5},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 298.15,
#    'pressure': 1010,
#    'humidity': 94,
#    'temp_min': 298.15,
#    'temp_max': 298.15},
#   'visibility': 6000,
#   'wind': {'speed': 2.1, 'deg': 190},
#   'clouds': {'all': 40},
#   'dt': 1574534225,
#   'sys': {'type': 1,
#    'id': 9412,
#    'country': 'ID',
#    'sunrise': 1574550816,
#    'sunset': 1574593815},
#   'timezone': 25200,
#   'id': 1215199,
#   'name': 'Deli Tua',
#   'cod': 200},
#  'ribeira grande': {'coord': {'lon': -28.7, 'lat': 38.52},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1014,
#    'humidity': 88,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 10000,
#   'wind': {'speed': 9.3, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1574534226,
#   'sys': {'type': 1,
#    'id': 6883,
#    'country': 'PT',
#    'sunrise': 1574498704,
#    'sunset': 1574534252},
#   'timezone': -3600,
#   'id': 3372707,
#   'name': 'Ribeira Grande',
#   'cod': 200},
#  'saint-philippe': {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 274.61,
#    'pressure': 1011,
#    'humidity': 64,
#    'temp_min': 273.71,
#    'temp_max': 275.93},
#   'visibility': 14484,
#   'wind': {'speed': 5.1, 'deg': 210},
#   'clouds': {'all': 90},
#   'dt': 1574534227,
#   'sys': {'type': 1,
#    'id': 820,
#    'country': 'CA',
#    'sunrise': 1574510589,
#    'sunset': 1574543865},
#   'timezone': -18000,
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  'rio gallegos': {'coord': {'lon': -69.22, 'lat': -51.62},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 289.15,
#    'pressure': 1001,
#    'humidity': 41,
#    'temp_min': 289.15,
#    'temp_max': 289.15},
#   'visibility': 10000,
#   'wind': {'speed': 19, 'deg': 20, 'gust': 24.2},
#   'clouds': {'all': 90},
#   'dt': 1574533944,
#   'sys': {'type': 1,
#    'id': 8293,
#    'country': 'AR',
#    'sunrise': 1574497524,
#    'sunset': 1574554885},
#   'timezone': -10800,
#   'id': 3838859,
#   'name': 'Rio Gallegos',
# ...
#   'dt': 1574534817,
#   'sys': {'type': 1,
#    'id': 1074,
#    'country': 'DZ',
#    'sunrise': 1574489916,
#    'sunset': 1574526088},
#   'timezone': 3600,
#   'id': 2501152,
#   'name': 'Constantine',
#   'cod': 200},
#  'saint anthony': {'coord': {'lon': -111.68, 'lat': 43.97},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 275.68,
#    'pressure': 1029,
#    'humidity': 74,
#    'temp_min': 274.15,
#    'temp_max': 278.15},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 60},
#   'clouds': {'all': 90},
#   'dt': 1574534818,
#   'sys': {'type': 1,
#    'id': 5735,
#    'country': 'US',
#    'sunrise': 1574519513,
#    'sunset': 1574553282},
#   'timezone': -25200,
#   'id': 5606187,
#   'name': 'Saint Anthony',
#   'cod': 200},
#  'cheuskiny': {'cod': '404', 'message': 'city not found'},
#  'road town': {'coord': {'lon': -64.62, 'lat': 18.42},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 300.15,
#    'pressure': 1013,
#    'humidity': 62,
#    'temp_min': 299.26,
#    'temp_max': 302.15},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'gust': 9.3},
#   'clouds': {'all': 40},
#   'dt': 1574534820,
#   'sys': {'type': 1,
#    'id': 8786,
#    'country': 'VG',
#    'sunrise': 1574504975,
#    'sunset': 1574545226},
#   'timezone': -14400,
#   'id': 3577430,
#   'name': 'Road Town',
#   'cod': 200},
#  'bonnyville': {'coord': {'lon': -110.74, 'lat': 54.27},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 281.15,
#    'pressure': 1000,
#    'humidity': 52,
#    'temp_min': 281.15,
#    'temp_max': 281.15},
#   'visibility': 24140,
#   'wind': {'speed': 7.7, 'deg': 270, 'gust': 10.8},
#   'clouds': {'all': 20},
#   'dt': 1574534821,
#   'sys': {'type': 1,
#    'id': 870,
#    'country': 'CA',
#    'sunrise': 1574521597,
#    'sunset': 1574550746},
#   'timezone': -25200,
#   'id': 5905616,
#   'name': 'Bonnyville',
#   'cod': 200},
#  'udachnyy': {'coord': {'lon': 112.4, 'lat': 66.42},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 244.15,
#    'pressure': 1007,
#    'humidity': 68,
#    'temp_min': 244.15,
#    'temp_max': 244.15},
#   'visibility': 2500,
#   'wind': {'speed': 1, 'deg': 240},
#   'clouds': {'all': 90},
#   'dt': 1574534822,
#   'sys': {'type': 1,
#    'id': 8846,
#    'country': 'RU',
#    'sunrise': 1574560513,
#    'sunset': 1574577536},
#   'timezone': 32400,
#   'id': 2014624,
#   'name': 'Udachnyy',
#   'cod': 200},
#  'palmer': {'coord': {'lon': 139.16, 'lat': -34.85},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 283.65,
#    'pressure': 1018,
#    'humidity': 81,
#    'temp_min': 281.48,
#    'temp_max': 284.82},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 30},
#   'clouds': {'all': 1},
#   'dt': 1574534824,
#   'sys': {'type': 1,
#    'id': 9566,
#    'country': 'AU',
#    'sunrise': 1574537128,
#    'sunset': 1574588073},
#   'timezone': 37800,
#   'id': 2067070,
#   'name': 'Palmer',
#   'cod': 200},
#  'deputatskiy': {'coord': {'lon': 139.9, 'lat': 69.3},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 242.44,
#    'pressure': 1019,
#    'humidity': 92,
#    'temp_min': 242.44,
#    'temp_max': 242.44,
#    'sea_level': 1019,
#    'grnd_level': 958},
#   'wind': {'speed': 1.98, 'deg': 264},
#   'clouds': {'all': 100},
#   'dt': 1574534825,
#   'sys': {'country': 'RU', 'sunrise': 1574557670, 'sunset': 1574567176},
#   'timezone': 36000,
#   'id': 2028164,
#   'name': 'Deputatskiy',
#   'cod': 200},
#  'ntcheu': {'coord': {'lon': 34.64, 'lat': -14.82},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 293.26,
#    'pressure': 1010,
#    'humidity': 87,
#    'temp_min': 293.26,
#    'temp_max': 293.26,
#    'sea_level': 1010,
#    'grnd_level': 862},
#   'wind': {'speed': 2.71, 'deg': 145},
#   'rain': {'3h': 6.06},
#   'clouds': {'all': 100},
#   'dt': 1574534826,
#   'sys': {'country': 'MW', 'sunrise': 1574478107, 'sunset': 1574524440},
#   'timezone': 7200,
#   'id': 924492,
#   'name': 'Ntcheu',
#   'cod': 200},
#  'krasnoselkup': {'cod': '404', 'message': 'city not found'},
#  'iqaluit': {'coord': {'lon': -68.52, 'lat': 63.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 269.97,
#    'pressure': 994,
#    'humidity': 68,
#    'temp_min': 269.82,
#    'temp_max': 270.15},
#   'visibility': 48279,
#   'wind': {'speed': 4.6, 'deg': 170},
#   'clouds': {'all': 75},
#   'dt': 1574534828,
#   'sys': {'type': 1,
#    'id': 797,
#    'country': 'CA',
#    'sunrise': 1574515410,
#    'sunset': 1574536663},
#   'timezone': -18000,
#   'id': 5983720,
#   'name': 'Iqaluit',
#   'cod': 200},
#  'progreso': {'coord': {'lon': -56.22, 'lat': -34.68},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 293.49,
#    'pressure': 1023,
#    'humidity': 49,
#    'temp_min': 292.04,
#    'temp_max': 295.37},
#   'visibility': 10000,
#   'wind': {'speed': 7.2, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1574534830,
#   'sys': {'type': 1,
#    'id': 8687,
#    'country': 'UY',
#    'sunrise': 1574497654,
#    'sunset': 1574548514},
#   'timezone': -10800,
#   'id': 3440963,
#   'name': 'Progreso',
#   'cod': 200},
#  'tateyama': {'coord': {'lon': 137.31, 'lat': 36.66},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 281.72,
#    'pressure': 1022,
#    'humidity': 93,
#    'temp_min': 279.82,
#    'temp_max': 285.37},
#   'wind': {'speed': 0.45, 'deg': 127, 'gust': 0.89},
#   'clouds': {'all': 4},
#   'dt': 1574534831,
#   'sys': {'type': 3,
#    'id': 2011552,
#    'country': 'JP',
#    'sunrise': 1574545028,
#    'sunset': 1574581061},
#   'timezone': 32400,
#   'id': 1849876,
#   'name': 'Tateyama',
#   'cod': 200},
#  'mirandopolis': {'coord': {'lon': -51.1, 'lat': -21.13},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': 307.01,
#    'pressure': 1005,
#    'humidity': 35,
#    'temp_min': 307.01,
#    'temp_max': 307.01,
#    'sea_level': 1005,
#    'grnd_level': 962},
#   'wind': {'speed': 3.09, 'deg': 224},
#   'clouds': {'all': 35},
#   'dt': 1574534832,
#   'sys': {'country': 'BR', 'sunrise': 1574498051, 'sunset': 1574545659},
#   'timezone': -10800,
#   'id': 3457107,
#   'name': 'Mirandopolis',
#   'cod': 200},
#  'ileza': {'coord': {'lon': 43.9, 'lat': 61.05},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 261.83,
#    'pressure': 1038,
#    'humidity': 88,
#    'temp_min': 261.83,
#    'temp_max': 261.83,
#    'sea_level': 1038,
#    'grnd_level': 1015},
#   'wind': {'speed': 1.71, 'deg': 243},
#   'clouds': {'all': 63},
#   'dt': 1574534833,
#   'sys': {'country': 'RU', 'sunrise': 1574486915, 'sunset': 1574511187},
#   'timezone': 10800,
#   'id': 829291,
#   'name': 'Ileza',
#   'cod': 200},
#  'coihaique': {'coord': {'lon': -72.07, 'lat': -45.58},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.27,
#    'pressure': 1005,
#    'humidity': 39,
#    'temp_min': 292.15,
#    'temp_max': 294.15},
#   'visibility': 10000,
#   'wind': {'speed': 1, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1574534834,
#   'sys': {'type': 1,
#    'id': 8491,
#    'country': 'CL',
#    'sunrise': 1574499630,
#    'sunset': 1574554148},
#   'timezone': -10800,
#   'id': 3894426,
#   'name': 'Coihaique',
#   'cod': 200},
#  'poum': {'coord': {'lon': 20.71, 'lat': 41.28},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 277.15,
#    'pressure': 1018,
#    'humidity': 86,
#    'temp_min': 277.15,
#    'temp_max': 277.15},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 320},
#   'clouds': {'all': 40},
#   'dt': 1574534836,
#   'sys': {'type': 1,
#    'id': 7013,
#    'country': 'MK',
#    'sunrise': 1574487260,
#    'sunset': 1574521975},
#   'timezone': 3600,
#   'id': 787487,
#   'name': 'Poum',
#   'cod': 200},
#  'katsuura': {'coord': {'lon': 134.5, 'lat': 33.93},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 284.94,
#    'pressure': 1022,
#    'humidity': 87,
#    'temp_min': 284.82,
#    'temp_max': 285.15},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 300},
#   'clouds': {'all': 20},
#   'dt': 1574534837,
#   'sys': {'type': 1,
#    'id': 8027,
#    'country': 'JP',
#    'sunrise': 1574545335,
#    'sunset': 1574582104},
#   'timezone': 32400,
#   'id': 1865309,
#   'name': 'Katsuura',
#   'cod': 200},
#  'sheridan': {'coord': {'lon': -105.03, 'lat': 39.65},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 280.88,
#    'pressure': 1020,
#    'humidity': 39,
#    'temp_min': 276.15,
#    'temp_max': 283.15},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 200},
#   'rain': {'1h': 1.33},
#   'clouds': {'all': 1},
#   'dt': 1574534838,
#   'sys': {'type': 1,
#    'id': 3958,
#    'country': 'US',
#    'sunrise': 1574517206,
#    'sunset': 1574552396},
#   'timezone': -25200,
#   'id': 5438542,
#   'name': 'Sheridan',
#   'cod': 200},
#  'cassilandia': {'coord': {'lon': -51.73, 'lat': -19.11},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 307.93,
#    'pressure': 1007,
#    'humidity': 33,
#    'temp_min': 307.93,
#    'temp_max': 307.93,
#    'sea_level': 1007,
#    'grnd_level': 952},
#   'wind': {'speed': 3.16, 'deg': 238},
#   'clouds': {'all': 58},
#   'dt': 1574534839,
#   'sys': {'country': 'BR', 'sunrise': 1574498411, 'sunset': 1574545602},
#   'timezone': -14400,
#   'id': 3466750,
#   'name': 'Cassilandia',
#   'cod': 200},
#  'henties bay': {'coord': {'lon': 14.28, 'lat': -22.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 290.37,
#    'pressure': 1015,
#    'humidity': 82,
#    'temp_min': 290.37,
#    'temp_max': 290.37},
#   'wind': {'speed': 4.47, 'deg': 209, 'gust': 7.6},
#   'clouds': {'all': 0},
#   'dt': 1574534840,
#   'sys': {'type': 3,
#    'id': 2012545,
#    'country': 'NA',
#    'sunrise': 1574482256,
#    'sunset': 1574530065},
#   'timezone': 7200,
#   'id': 3356832,
#   'name': 'Henties Bay',
#   'cod': 200},
#  'tarko-sale': {'coord': {'lon': 77.78, 'lat': 64.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 254.82,
#    'pressure': 1021,
#    'humidity': 86,
#    'temp_min': 254.82,
#    'temp_max': 254.82},
#   'wind': {'speed': 5.34, 'deg': 343},
#   'clouds': {'all': 0},
#   'dt': 1574534842,
#   'sys': {'type': 3,
#    'id': 265489,
#    'country': 'RU',
#    'sunrise': 1574481004,
#    'sunset': 1574500831},
#   'timezone': 18000,
#   'id': 1490085,
#   'name': 'Tarko-Sale',
#   'cod': 200},
#  'sikonge': {'coord': {'lon': 32.75, 'lat': -5.63},
#   'weather': [{'id': 200,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm with light rain',
#     'icon': '11n'}],
#   'base': 'stations',
#   'main': {'temp': 293.15,
#    'pressure': 1016,
#    'humidity': 94,
#    'temp_min': 293.15,
#    'temp_max': 293.15},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 20},
#   'clouds': {'all': 75},
#   'dt': 1574534843,
#   'sys': {'type': 1,
#    'id': 2625,
#    'country': 'TZ',
#    'sunrise': 1574479413,
#    'sunset': 1574524041},
#   'timezone': 10800,
#   'id': 149929,
#   'name': 'Sikonge',
#   'cod': 200},
#  'charlestown': {'coord': {'lon': -71.64, 'lat': 41.38},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 280.12,
#    'pressure': 1014,
#    'humidity': 36,
#    'temp_min': 278.71,
#    'temp_max': 281.48},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 280},
#   'clouds': {'all': 1},
#   'dt': 1574534844,
#   'sys': {'type': 1,
#    'id': 6272,
#    'country': 'US',
#    'sunrise': 1574509457,
#    'sunset': 1574544114},
#   'timezone': -18000,
#   'id': 5221384,
#   'name': 'Charlestown',
#   'cod': 200},
#  'myitkyina': {'coord': {'lon': 97.4, 'lat': 25.38},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 289.76,
#    'pressure': 1016,
#    'humidity': 83,
#    'temp_min': 289.76,
#    'temp_max': 289.76,
#    'sea_level': 1016,
#    'grnd_level': 985},
#   'wind': {'speed': 1.12, 'deg': 25},
#   'clouds': {'all': 53},
#   'dt': 1574534845,
#   'sys': {'country': 'MM', 'sunrise': 1574553230, 'sunset': 1574592021},
#   'timezone': 23400,
#   'id': 1307741,
#   'name': 'Myitkyina',
#   'cod': 200},
#  'namibe': {'coord': {'lon': 12.15, 'lat': -15.19},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': 294.76,
#    'pressure': 1011,
#    'humidity': 84,
#    'temp_min': 294.76,
#    'temp_max': 294.76,
#    'sea_level': 1011,
#    'grnd_level': 1011},
#   'wind': {'speed': 7.55, 'deg': 196},
#   'clouds': {'all': 32},
#   'dt': 1574534846,
#   'sys': {'country': 'AO', 'sunrise': 1574483469, 'sunset': 1574529875},
#   'timezone': 3600,
#   'id': 3347019,
#   'name': 'Namibe',
#   'cod': 200},
#  'muros': {'coord': {'lon': -9.06, 'lat': 42.77},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 283.77,
#    'pressure': 1011,
#    'humidity': 100,
#    'temp_min': 281.15,
#    'temp_max': 285.93},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 290},
#   'clouds': {'all': 40},
#   'dt': 1574534847,
#   'sys': {'type': 1,
#    'id': 6434,
#    'country': 'ES',
#    'sunrise': 1574494655,
#    'sunset': 1574528872},
#   'timezone': 3600,
#   'id': 3115824,
#   'name': 'Muros',
#   'cod': 200},
#  'san policarpo': {'coord': {'lon': 125.51, 'lat': 12.18},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 300.27,
#    'pressure': 1009,
#    'humidity': 86,
#    'temp_min': 300.27,
#    'temp_max': 300.27,
#    'sea_level': 1009,
#    'grnd_level': 1009},
#   'wind': {'speed': 3.21, 'deg': 14},
#   'rain': {'3h': 2.06},
#   'clouds': {'all': 50},
#   'dt': 1574534849,
#   'sys': {'country': 'PH', 'sunrise': 1574545165, 'sunset': 1574586590},
#   'timezone': 28800,
#   'id': 1688696,
#   'name': 'San Policarpo',
#   'cod': 200},
#  'rassvet': {'coord': {'lon': 45.47, 'lat': 49.11},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 267.8,
#    'pressure': 1040,
#    'humidity': 68,
#    'temp_min': 267.8,
#    'temp_max': 267.8,
#    'sea_level': 1040,
#    'grnd_level': 1037},
#   'wind': {'speed': 3.24, 'deg': 62},
#   'clouds': {'all': 0},
#   'dt': 1574534850,
#   'sys': {'country': 'RU', 'sunrise': 1574482771, 'sunset': 1574514577},
#   'timezone': 14400,
#   'id': 528075,
#   'name': 'Rassvet',
#   'cod': 200},
#  'carutapera': {'coord': {'lon': -46.02, 'lat': -1.2},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 300.78,
#    'pressure': 1009,
#    'humidity': 78,
#    'temp_min': 300.78,
#    'temp_max': 300.78,
#    'sea_level': 1009,
#    'grnd_level': 1009},
#   'wind': {'speed': 5.14, 'deg': 75},
#   'clouds': {'all': 100},
#   'dt': 1574534851,
#   'sys': {'country': 'BR', 'sunrise': 1574498717, 'sunset': 1574542555},
#   'timezone': -10800,
#   'id': 3402648,
#   'name': 'Carutapera',
#   'cod': 200}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weat_df = pd.DataFrame(pull2_di)
weat_piv = weat_df.transpose()
weat_piv

#no need for below
#cit_df = pd.DataFrame(cities)
#cit_df.index = cit_df[0]
#cit_df

#comb_df = pd.DataFrame(list(zip(cit_df[0], weat_piv.index)))
#comb_df = comb_df.set_index(0)
#con_df =  pd.concat([comb_df, weat_piv], axis=1)
#con_df = con_df.set_index(1)
#con_df

weat_piv
del weat_piv['message']
del weat_piv['cod']
weat_drop = weat_piv.dropna(how='all')
weat_drop.to_csv('CityWeather.csv')
weat_drop
# Out:
#                                         coord  \
# mataura        {'lon': 168.86, 'lat': -46.19}
# atuona          {'lon': -139.03, 'lat': -9.8}
# thai binh       {'lon': 106.33, 'lat': 20.45}
# pryazha          {'lon': 33.62, 'lat': 61.69}
# saskylakh       {'lon': 114.09, 'lat': 71.97}
# ...                                       ...
# namibe          {'lon': 12.15, 'lat': -15.19}
# muros            {'lon': -9.06, 'lat': 42.77}
# san policarpo   {'lon': 125.51, 'lat': 12.18}
# rassvet          {'lon': 45.47, 'lat': 49.11}
# carutapera       {'lon': -46.02, 'lat': -1.2}
#
#                                                          weather      base  \
# mataura        [{'id': 803, 'main': 'Clouds', 'description': ...  stations
# atuona         [{'id': 800, 'main': 'Clear', 'description': '...     model
# thai binh      [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# pryazha        [{'id': 803, 'main': 'Clouds', 'description': ...  stations
# saskylakh      [{'id': 804, 'main': 'Clouds', 'description': ...     model
# ...                                                          ...       ...
# namibe         [{'id': 802, 'main': 'Clouds', 'description': ...     model
# muros          [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# san policarpo  [{'id': 500, 'main': 'Rain', 'description': 'l...     model
# rassvet        [{'id': 800, 'main': 'Clear', 'description': '...     model
# carutapera     [{'id': 804, 'main': 'Clouds', 'description': ...     model
#
#                                                             main  \
# mataura        {'temp': 286.48, 'pressure': 1005, 'humidity':...
# atuona         {'temp': 299.6, 'pressure': 1010, 'humidity': ...
# thai binh      {'temp': 297.15, 'pressure': 1014, 'humidity':...
# pryazha        {'temp': 262.15, 'pressure': 1033, 'humidity':...
# saskylakh      {'temp': 243.2, 'pressure': 1017, 'humidity': ...
# ...                                                          ...
# namibe         {'temp': 294.76, 'pressure': 1011, 'humidity':...
# muros          {'temp': 283.77, 'pressure': 1011, 'humidity':...
# san policarpo  {'temp': 300.27, 'pressure': 1009, 'humidity':...
# rassvet        {'temp': 267.8, 'pressure': 1040, 'humidity': ...
# carutapera     {'temp': 300.78, 'pressure': 1009, 'humidity':...
#
#                                                      wind        clouds  \
# mataura        {'speed': 8.94, 'deg': 226, 'gust': 16.99}   {'all': 83}
# atuona                         {'speed': 7.22, 'deg': 72}    {'all': 3}
# thai binh                      {'speed': 2.6, 'deg': 110}   {'all': 20}
# pryazha                                      {'speed': 1}   {'all': 67}
# saskylakh                     {'speed': 1.06, 'deg': 113}   {'all': 98}
# ...                                                   ...           ...
# namibe                        {'speed': 7.55, 'deg': 196}   {'all': 32}
# muros                          {'speed': 2.1, 'deg': 290}   {'all': 40}
# san policarpo                  {'speed': 3.21, 'deg': 14}   {'all': 50}
# rassvet                        {'speed': 3.24, 'deg': 62}    {'all': 0}
# carutapera                     {'speed': 5.14, 'deg': 75}  {'all': 100}
#
#                        dt                                                sys  \
# mataura        1574534124  {'type': 3, 'id': 2008959, 'country': 'NZ', 's...
# atuona         1574534125  {'country': 'PF', 'sunrise': 1574520264, 'suns...
# thai binh      1574534126  {'type': 1, 'id': 9302, 'country': 'VN', 'sunr...
# pryazha        1574534127  {'type': 1, 'id': 8929, 'country': 'RU', 'sunr...
# saskylakh      1574534130       {'country': 'RU', 'sunrise': 0, 'sunset': 0}
# ...                   ...                                                ...
# namibe         1574534846  {'country': 'AO', 'sunrise': 1574483469, 'suns...
# muros          1574534847  {'type': 1, 'id': 6434, 'country': 'ES', 'sunr...
# san policarpo  1574534849  {'country': 'PH', 'sunrise': 1574545165, 'suns...
# rassvet        1574534850  {'country': 'RU', 'sunrise': 1574482771, 'suns...
# carutapera     1574534851  {'country': 'BR', 'sunrise': 1574498717, 'suns...
#
#               timezone       id           name visibility snow          rain
# mataura          46800  6201424        Mataura        NaN  NaN           NaN
# atuona          -34200  4020109         Atuona        NaN  NaN           NaN
# thai binh        25200  1566346      Thai Binh       9000  NaN           NaN
# pryazha          10800   504409        Pryazha      10000  NaN           NaN
# saskylakh        32400  2017155      Saskylakh        NaN  NaN           NaN
# ...                ...      ...            ...        ...  ...           ...
# namibe            3600  3347019         Namibe        NaN  NaN           NaN
# muros             3600  3115824          Muros      10000  NaN           NaN
# san policarpo    28800  1688696  San Policarpo        NaN  NaN  {'3h': 2.06}
# rassvet          14400   528075        Rassvet        NaN  NaN           NaN
# carutapera      -10800  3402648     Carutapera        NaN  NaN           NaN
#
# [543 rows x 14 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lat_ls = weat_drop['coord']
temp_ls = weat_drop['main']
lat_di = {}
temp_di = {}
drop_cit = weat_drop.index

for city in drop_cit:
    lat_di[city] = lat_ls[city]['lat']    
    temp_di[city] = temp_ls[city]['temp']
    
#convert kelvin to farenheit
temp_f = []

for val in temp_di.values():
    temp_f.append((val - 273.15) * (9/5) + 32)

    
lat_t_df = pd.DataFrame(list(zip(lat_di.values(), temp_f)), columns=['Latitude', 'Temperature'],index=lat_di.keys())
lat_t_df.to_csv('Lat_Vs_Temp.csv')
lat_t_df
# Out:
#                Latitude  Temperature
# mataura          -46.19       55.994
# atuona            -9.80       79.610
# thai binh         20.45       75.200
# pryazha           61.69       12.200
# saskylakh         71.97      -21.910
# ...                 ...          ...
# namibe           -15.19       70.898
# muros             42.77       51.116
# san policarpo     12.18       80.816
# rassvet           49.11       22.370
# carutapera        -1.20       81.734
#
# [543 rows x 2 columns]

# %%
plt.scatter(lat_t_df['Latitude'], lat_t_df['Temperature'])
plt.title("Temperature vs Latitude")
plt.ylabel('Temperature (F)')
plt.xlabel("Latitude")
plt.grid(True)
# Save the Figure
plt.savefig('Temperature vs Lat.png')
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
lat_ls = weat_drop['coord']
hum_ls = weat_drop['main']
lat_di = {}
hum_di = {}
drop_cit = weat_drop.index


for city in drop_cit:
    lat_di[city] = lat_ls[city]['lat']    
    hum_di[city] = hum_ls[city]['humidity']
    
lat_h_df = pd.DataFrame(list(zip(lat_di.values(), hum_di.values())), columns=['Latitude', 'Humidity (%)'],index=lat_di.keys())
lat_h_df.to_csv('Lat_Vs_Humidity.csv')
lat_h_df
# Out:
#                Latitude  Humidity (%)
# mataura          -46.19            87
# atuona            -9.80            75
# thai binh         20.45            88
# pryazha           61.69            92
# saskylakh         71.97            99
# ...                 ...           ...
# namibe           -15.19            84
# muros             42.77           100
# san policarpo     12.18            86
# rassvet           49.11            68
# carutapera        -1.20            78
#
# [543 rows x 2 columns]

# %%
plt.scatter(lat_h_df['Latitude'], lat_h_df['Humidity (%)'])
plt.title("Humidity vs Latitude")
plt.ylabel('Humidity %')
plt.xlabel("Latitude")
plt.grid(True)
# Save the Figure
plt.savefig('Humidity vs Lat.png')
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
lat_ls = weat_drop['coord']
cloud_ls = weat_drop['clouds']
lat_di = {}
cloud_di = {}
drop_cit = weat_drop.index


for city in drop_cit:
    lat_di[city] = lat_ls[city]['lat']    
    cloud_di[city] = cloud_ls[city]['all']
    
lat_c_df = pd.DataFrame(list(zip(lat_di.values(), cloud_di.values())), columns=['Latitude', 'Cloudiness (%)'],index=lat_di.keys())
lat_c_df.to_csv('Lat_Vs_Cloudiness.csv')
lat_c_df
# Out:
#                Latitude  Cloudiness (%)
# mataura          -46.19              83
# atuona            -9.80               3
# thai binh         20.45              20
# pryazha           61.69              67
# saskylakh         71.97              98
# ...                 ...             ...
# namibe           -15.19              32
# muros             42.77              40
# san policarpo     12.18              50
# rassvet           49.11               0
# carutapera        -1.20             100
#
# [543 rows x 2 columns]

# %%
plt.scatter(lat_c_df['Latitude'], lat_c_df['Cloudiness (%)'])
plt.title("Cloudiness vs Latitude")
plt.ylabel('Cloudiness %')
plt.xlabel("Latitude")
plt.grid(True)
# Save the Figure
plt.savefig('Cloudiness vs Lat.png')
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
lat_ls = weat_drop['coord']
wind_ls = weat_drop['wind']
lat_di = {}
wind_di = {}
drop_cit = weat_drop.index

for city in drop_cit:
    lat_di[city] = lat_ls[city]['lat']    
    wind_di[city] = wind_ls[city]['speed']
    
speed = []
    
#convert wind speed from m/s to mph
for val in wind_di.values():
    speed.append(val * 2.236936)
    
lat_w_df = pd.DataFrame(list(zip(lat_di.values(), speed)), columns=['Latitude', 'Wind Speed (mph)'],index=lat_di.keys())
lat_w_df.to_csv('Lat_Vs_WindSpeed.csv')
lat_w_df
# Out:
#                Latitude  Wind Speed (mph)
# mataura          -46.19         19.998208
# atuona            -9.80         16.150678
# thai binh         20.45          5.816034
# pryazha           61.69          2.236936
# saskylakh         71.97          2.371152
# ...                 ...               ...
# namibe           -15.19         16.888867
# muros             42.77          4.697566
# san policarpo     12.18          7.180565
# rassvet           49.11          7.247673
# carutapera        -1.20         11.497851
#
# [543 rows x 2 columns]

# %%
plt.scatter(lat_w_df['Latitude'], lat_w_df['Wind Speed (mph)'])
plt.title("Wind Speed vs Latitude")
plt.ylabel('Wind Speed (mph)')
plt.xlabel("Latitude")
plt.grid(True)
# Save the Figure
plt.savefig('Wind Speed vs Lat.png')
# Show the Figure
plt.show()
